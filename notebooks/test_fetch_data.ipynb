# %%
import pandas as pd
from preprocessing import clean_raw_data, create_features, prepare_training_data
from fetch_data import fetch_weather


city = "Genève"
df_raw = fetch_weather(city, past_days=730)
# Out:
# Chargement des données locales depuis data/_genève_730d.csv

# %%
df_clean = clean_raw_data(df_raw)
print(f"🔍 Données nettoyées : {df_clean.shape}")
df_clean.tail()
# Out:
# 🔍 Données nettoyées : (731, 13)
#           time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 726 2025-04-04           19.100000            6.000000           0.000000
# 727 2025-04-05           19.200000            6.800000           0.000000
# 728 2025-04-06           14.600000            7.000000           0.000000
# 729 2025-04-07            6.200000            5.000000           0.000000
# 730 2025-04-08           16.604795            8.356164           3.643073
#
#      rain_sum  showers_sum  snowfall_sum  windspeed_10m_max  \
# 726  0.000000          0.0      0.000000           8.000000
# 727  0.000000          0.0      0.000000           8.400000
# 728  0.000000          0.0      0.000000          25.100000
# 729  0.000000          0.0      0.000000          16.500000
# 730  3.555418          0.0      0.061358          12.748082
#
#      windgusts_10m_max  sunshine_duration  shortwave_radiation_sum  \
# 726          18.400000       42218.010000                20.700000
# 727          20.900000       42840.750000                20.430000
# 728          52.200000       43402.930000                22.080000
# 729          38.900000       22948.084000                 7.364000
# 730          27.706301       30844.581043                13.699684
#
#      et0_fao_evapotranspiration  weathercode
# 726                    3.200000     3.000000
# 727                    3.240000     1.000000
# 728                    3.390000     3.000000
# 729                    0.880000     0.000000
# 730                    2.373882    33.772603

# %%
n_lags = 3
df_features = create_features(df_clean, n_lags=n_lags)
print(f"🔍 Données après `create_features` : {df_features.shape}")
df_features.tail()
# Out:
# 🔍 Données après `create_features` : (727, 49)
#           time  weathercode  target_temperature_2m_max  \
# 725 2025-04-03          3.0                  19.100000
# 726 2025-04-04          3.0                  19.200000
# 727 2025-04-05          1.0                  14.600000
# 728 2025-04-06          3.0                   6.200000
# 729 2025-04-07          0.0                  16.604795
#
#      target_temperature_2m_min  target_temperature_2m_mean  target_will_rain  \
# 725                   6.000000                   12.550000                 0
# 726                   6.800000                   13.000000                 0
# 727                   7.000000                   10.800000                 0
# 728                   5.000000                    5.600000                 0
# 729                   8.356164                   12.480479                 1
#
#      target_windspeed_10m_max  temp_amplitude  rain_to_precip_ratio  \
# 725                  8.000000            13.3                   0.0
# 726                  8.400000            13.1                   0.0
# 727                 25.100000            12.4                   0.0
# 728                 16.500000             7.6                   0.0
# 729                 12.748082             1.2                   0.0
#
#      wind_diff  ...  sunshine_duration_lag_2  sunshine_duration_lag_3  \
# 725       12.7  ...                 40030.78                 41654.40
# 726       10.4  ...                 42056.66                 40030.78
# 727       12.5  ...                 42429.77                 42056.66
# 728       27.1  ...                 42218.01                 42429.77
# 729       22.4  ...                 42840.75                 42218.01
#
#      shortwave_radiation_sum_lag_1  shortwave_radiation_sum_lag_2  \
# 725                          19.21                          21.26
# 726                          21.11                          19.21
# 727                          20.70                          21.11
# 728                          20.43                          20.70
# 729                          22.08                          20.43
#
#      shortwave_radiation_sum_lag_3  et0_fao_evapotranspiration_lag_1  \
# 725                          20.88                              2.48
# 726                          21.26                              3.02
# 727                          19.21                              3.20
# 728                          21.11                              3.24
# 729                          20.70                              3.39
#
#      et0_fao_evapotranspiration_lag_2  et0_fao_evapotranspiration_lag_3  \
# 725                              2.96                              2.95
# 726                              2.48                              2.96
# 727                              3.02                              2.48
# 728                              3.20                              3.02
# 729                              3.24                              3.20
#
#      temp_max_rolling_mean_3  rain_sum_rolling_std_3
# 725                13.700000                0.057735
# 726                16.500000                0.000000
# 727                18.500000                0.000000
# 728                17.633333                0.000000
# 729                13.333333                0.000000
#
# [5 rows x 49 columns]

# %%
target_columns = [
    "target_temperature_2m_max",
    "target_temperature_2m_min",
    "target_temperature_2m_mean",
    "target_will_rain",
    "target_windspeed_10m_max"
]

X, Y, scaler = prepare_training_data(df_features, target_columns)
print(f"✅ X.shape = {X.shape}, Y.shape = {Y.shape}")
# Out:
# ✅ X.shape = (727, 43), Y.shape = (727, 5)

# %%
if len(X) > 0:
    print("Dernier échantillon (X):", X[-1])
    print("Dernier échantillon (Y):", Y[-1])
else:
    print("❌ Aucune donnée disponible dans X")
# Out:
# Dernier échantillon (X): [-1.21404492 -2.26789553 -1.11048165  1.293002   -0.53578781 -0.80137232
#   1.41973134 -0.14232693 -0.24620503  0.31313321  0.30196802 -0.20645037
#  -0.2358748  -0.35452919 -0.52538156 -0.52538156 -0.52538156 -0.5202875
#  -0.5202875  -0.5202875   0.          0.          0.         -0.12018852
#  -0.12018852 -0.12018852  2.15866561 -0.75855203 -0.82974436  2.19845087
#  -0.60873896 -0.83442234  0.85113847  0.81472233  0.77235931  1.06537832
#   0.85749395  0.89113625  0.62005369  0.5291801   0.50515634 -0.40959977
#  -0.79015599]
# Dernier échantillon (Y): [16.60479452  8.35616438 12.48047945  1.         12.74808219]

# %%
print("Colonnes avec NaN dans df_features :")
print(df_features.isna().sum()[df_features.isna().sum() > 0])
# Out:
# Colonnes avec NaN dans df_features :
# Series([], dtype: int64)
